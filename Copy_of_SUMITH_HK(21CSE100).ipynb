# %% [markdown]
# <a href="https://colab.research.google.com/github/sumith-hk/COB-PYTHON-DEVELOPMENT-INTERN/blob/main/Copy_of_SUMITH_HK(21CSE100).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/IMDB Top 250 Movies.csv')

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df.tail()
# Out:
#      rank                name  year  rating                       genre  \
# 245   246            The Help  2011     8.1                       Drama
# 246   247         Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248             Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249              Gandhi  1982     8.0     Biography,Drama,History
# 249   250  Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 245       25000000      216639112
# ...

# %%
df.shape
# Out:
# (250, 13)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.iloc[0:2,0:2]
# Out:
#    rank                      name
# 0     1  The Shawshank Redemption
# 1     2             The Godfather

# %%
df.loc[0:3,("budget","box_office")]
# Out:
#       budget  box_office
# 0   25000000    28884504
# 1    6000000   250341816
# 2  185000000  1006234167
# 3   13000000    47961919

# %%
df.drop([1,2,3],axis=0)
# Out:
#      rank                                           name  year  rating  \
# 0       1                       The Shawshank Redemption  1994     9.3
# 4       5                                   12 Angry Men  1957     9.0
# 5       6                               Schindler's List  1993     9.0
# 6       7  The Lord of the Rings: The Return of the King  2003     9.0
# 7       8                                   Pulp Fiction  1994     8.9
# ..    ...                                            ...   ...     ...
# 245   246                                       The Help  2011     8.1
# 246   247                                    Dersu Uzala  1975     8.2
# 247   248                                        Aladdin  1992     8.0
# 248   249                                         Gandhi  1982     8.0
# 249   250                             Dances with Wolves  1990     8.0
#
#                           genre certificate run_time  \
# 0                         Drama           R   2h 22m
# ...

# %%
df.drop("genre",axis=1)
# Out:
#      rank                      name  year  rating certificate run_time  \
# 0       1  The Shawshank Redemption  1994     9.3           R   2h 22m
# 1       2             The Godfather  1972     9.2           R   2h 55m
# 2       3           The Dark Knight  2008     9.0       PG-13   2h 32m
# 3       4     The Godfather Part II  1974     9.0           R   3h 22m
# 4       5              12 Angry Men  1957     9.0    Approved   1h 36m
# ..    ...                       ...   ...     ...         ...      ...
# 245   246                  The Help  2011     8.1       PG-13   2h 26m
# 246   247               Dersu Uzala  1975     8.2           G   2h 22m
# 247   248                   Aladdin  1992     8.0           G   1h 30m
# 248   249                    Gandhi  1982     8.0          PG   3h 11m
# 249   250        Dances with Wolves  1990     8.0       PG-13    3h 1m
#
#                                                tagline         budget  \
# ...

# %%
df.mean()
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# rank       125.5000
# year      1986.3600
# rating       8.3072
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-18-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# rank       125.5
# year      1994.0
# rating       8.2
# dtype: float64

# %%
df.max()
# Out:
# rank                                                         250
# name                                                  Your Name.
# year                                                        2022
# rating                                                       9.3
# genre                                                    Western
# certificate                                                    X
# run_time                                           Not Available
# tagline                                       ventureComedyCrime
# budget                                              RF 115000000
# box_office                                         Not Available
# casts          Çetin Tekindor,Fikret Kuskan,Hümeyra,Ege Tanma...
# directors                                            Çagan Irmak
# writers                                              Çagan Irmak
# dtype: object

# %%
def mul(s):
  return s*2

# %%
df[['rank']].apply(mul)
# Out:
#      rank
# 0       2
# 1       4
# 2       6
# 3       8
# 4      10
# ..    ...
# 245   492
# 246   494
# 247   496
# 248   498
# 249   500
#
# [250 rows x 1 columns]

# %%
data={"name":["sumith","suprith","suhaas"],
      "age":[20,25,28]}

# %%
data["name"]
# Out:
# ['sumith', 'suprith', 'suhaas']

# %%
df=pd.DataFrame(data)

# %%
data
# Out:
# {'name': ['sumith', 'suprith', 'suhaas'], 'age': [20, 25, 28]}

# %%
df
# Out:
#       name  age
# 0   sumith   20
# 1  suprith   25
# 2   suhaas   28

# %%
df.drop([1],axis=0)
# Out:
#      name  age
# 0  sumith   20
# 2  suhaas   28

# %%
df.max()
# Out:
# name    suprith
# age          28
# dtype: object

# %%
df
# Out:
#       name  age
# 0   sumith   20
# 1  suprith   25
# 2   suhaas   28
